# %% [markdown]
# # **1. MySQLClient**
#
# - 파이썬에서 MySQL 데이터베이스와 상호작용하기 위해 사용하는 공식 라이브러리
# - PyMySQL, mysqlclient를 가장 많이 사용함
# - 사용법은 비슷하나 mysqlclient가 속도상으로도 유리하기 때문에 mysqlclient를 권장
# - SQLAlchemy를 실무에서 가장 많이 사용

# %%
import MySQLdb

# %% [markdown]
# ### 1. MySQL 접속
#
# ```
# MySQLdb.connect(host = 'IP주소', user = '사용자명', password = '비밀번호', db = '데이터베이스명')
# ```

# %%
db = MySQLdb.connect(host = 'localhost', user = 'root', password = '1234', db = 'ai')
db
# Out:
# <_mysql.connection open to 'localhost' at 000001E2FA830960>

# %% [markdown]
# ### 2. cursor 생성
# - 하나의 데이터베이스 connection에 대해 독립적으로 SQL문을 실행할 수 있는 작업환경을 제공하는 객체
# - 하나의 connection에 동시에 한 개의 cursor만 생성할 수 있으며, cursor를 통해 SQL문을 실행하면 실행결과를 튜플 단위로 반환

# %%
cur = db.cursor() # 쉽게말하면 sql실행 해주는 애
cur.execute("SELECT * FROM member")
# Out:
# 6

# %% [markdown]
# ### 3. SQL문의 결과 반환
# - fetchall(): 한번에 모든 TUPLE을 가져옴. 검색 결과가 매우 많으면 메모리 오버헤드 발생할 수 있음
# - fetchone(): 한번에 하나의 TUPLE을 가져옴. 다시 FETCHONE() 메서드를 호출하면 다음 데이터를 가져옴

# %%
data = cur.fetchall()
data
# Out:
# ((1,
#   'apple',
#   '1111',
#   '김사과',
#   '010-1111-1111',
#   'apple@apple.com',
#   '001011',
#   '4011111',
#   '12345',
#   '서울 서초구',
#   '양재동',
#   '111-11',
#   datetime.datetime(2026, 6, 5, 9, 49, 31),
#   150,
#   '여자'),
#  (2,
#   'banana',
#   '2222',
#   '반하나',
#   '010-2222-2222',
#   'banana@banana.com',
#   '001011',
#   '4011111',
#   '12345',
#   '서울 서초구',
#   '양재동',
#   '111-11',
#   datetime.datetime(2026, 6, 5, 9, 51, 53),
#   250,
#   '여자'),
#  (3,
#   'orange',
#   '3333',
#   '오렌지',
#   '010-3333-3333',
#   'orange@orange.com',
#   '001011',
#   '4011111',
#   '12345',
#   '서울 서초구',
#   '양재동',
#   '111-11',
#   datetime.datetime(2026, 6, 5, 9, 51, 54),
#   150,
#   '남자'),
#  (4,
#   'melon',
#   '4444',
#   '이메론',
#   '010-4444-4444',
#   'melon@melon.com',
#   '001011',
#   '4011111',
#   '12345',
#   '서울 서초구',
#   '양재동',
#   '111-11',
#   datetime.datetime(2026, 6, 5, 9, 52, 56),
#   150,
#   '남자'),
#  (5,
#   'cherry',
#   '5555',
#   '채리',
#   '010-5555-5555',
#   'cherry@cherry.com',
#   '001011',
#   '4011111',
#   '12345',
#   '서울 서초구',
#   '양재동',
#   '111-11',
#   datetime.datetime(2026, 6, 5, 9, 53, 39),
#   50,
#   '여자'),
#  (6,
#   'berry',
#   '6666',
#   '배애리',
#   '010-6666-6666',
#   'berry@berry.com',
#   '001011',
#   '4011111',
#   '12345',
#   '서울 서초구',
#   '양재동',
#   '111-11',
#   None,
#   100,
#   '여자'))

# %%
cur.execute("select userid, name, gender from member")
# Out:
# 6

# %%
row = cur.fetchone()
row
# Out:
# ('apple', '김사과', '여자')

# %%
row = cur.fetchone()
row
# Out:
# ('banana', '반하나', '여자')

# %%
row = cur.fetchone()
row
# Out:
# ('orange', '오렌지', '남자')

# %%
sql = "select userid, name, gender, hp from member"
cur.execute(sql)
# Out:
# 6

# %%
while True:
    row = cur.fetchone()
    if row:
        print(row)
    else: 
        break
# Out:
# ('apple', '김사과', '여자', '010-1111-1111')
# ('banana', '반하나', '여자', '010-2222-2222')
# ('orange', '오렌지', '남자', '010-3333-3333')
# ('melon', '이메론', '남자', '010-4444-4444')
# ('cherry', '채리', '여자', '010-5555-5555')
# ('berry', '배애리', '여자', '010-6666-6666')

# %% [markdown]
# ### 4. 딕셔너리 형태로 결과 반환
#
#
# ```
# cursor(MySQLdb.cursors.DictCursor)
# ```

# %%
cur = db.cursor(MySQLdb.cursors.DictCursor)
cur.execute(sql)

result = cur.fetchall()
result
# Out:
# ({'userid': 'apple', 'name': '김사과', 'gender': '여자', 'hp': '010-1111-1111'},
#  {'userid': 'banana', 'name': '반하나', 'gender': '여자', 'hp': '010-2222-2222'},
#  {'userid': 'orange', 'name': '오렌지', 'gender': '남자', 'hp': '010-3333-3333'},
#  {'userid': 'melon', 'name': '이메론', 'gender': '남자', 'hp': '010-4444-4444'},
#  {'userid': 'cherry', 'name': '채리', 'gender': '여자', 'hp': '010-5555-5555'},
#  {'userid': 'berry', 'name': '배애리', 'gender': '여자', 'hp': '010-6666-6666'})

# %%
cur.execute(sql)

while True:
    row = cur.fetchone()
    if row:
        print(f'아이디: {row['userid']}, 이름: {row['gender']}, 성별: {row['gender']}. 전화번호:{row['hp']}')
    else:
        break
# Out:
# 아이디: apple, 이름: 여자, 성별: 여자. 전화번호:010-1111-1111
# 아이디: banana, 이름: 여자, 성별: 여자. 전화번호:010-2222-2222
# 아이디: orange, 이름: 남자, 성별: 남자. 전화번호:010-3333-3333
# 아이디: melon, 이름: 남자, 성별: 남자. 전화번호:010-4444-4444
# 아이디: cherry, 이름: 여자, 성별: 여자. 전화번호:010-5555-5555
# 아이디: berry, 이름: 여자, 성별: 여자. 전화번호:010-6666-6666

# %% [markdown]
# ### 5. Cursor와 Connection 닫기

# %%
cur.close()
db.close()

# %% [markdown]
# # **2. 데이터 삽입하기**

# %%
db = MySQLdb.connect(host = 'localhost', user = 'root', password = '1234', db = 'ai')
cur = db.cursor()

# %%
sql = "insert into member (userid, userpw, name, hp, email, gender, ssn1, ssn2) values (%s, %s, %s, %s, %s, %s, %s, %s)"
data = ('mango', '8888', '마앙고', '010-8888-8888', 'mango@mango.com', '남자', '000000', '0000000')
cur.execute(sql, data)
db.commit()

# %%
sql = "insert into member (userid, userpw, name, hp, email, gender, ssn1, ssn2) values (%s, %s, %s, %s, %s, %s, %s, %s)"
data = [('pear', '9999', '배철수', '010-9999-9999', 'pear@pear.com', '남자', '000000', '0000000'), ('peach', '0000', '복숭아', '010-0000-0000', 'peach@peach.com', '남자', '000000', '0000000')]
cur.executemany(sql, data)
db.commit()

# %%
cur.close()
db.close()

# %% [markdown]
# ### 회원가입 프로그램

# %%
db = MySQLdb.connect(host = 'localhost', user = 'root', password = '1234', db = 'ai')
cur = db.cursor()

while True:
    try:
        userid = input("아이디 입력: ")
        userpw = input("비밀번호 입력: ")
        name = input('이름 입력:')
        hp = input('전화번호 입력:')
        email = input("이메일 입력: ")
        ssn1 = input("주민번호 앞자리: ")
        ssn2 = input("주민번호 뒷자리: ")
        zipcode = input("우편번호 입력: ")
        address1 = input("주소 입력: ")
        address2 = input("상세주소 입력: ")
        address3 = input("참고사항 입력: ")
        gender= input("성별 입력: ")
        sql = "insert into member (userid, userpw, name, hp, email, gender, ssn1, ssn2) values (%s, %s, %s, %s, %s, %s, %s, %s)"
        data = (userid, userpw, name, hp, email, gender, ssn1, ssn2, zipcode, address1, address2, address3)

        cur.execute(sql, data)
        db.commit()
        print("가입됨")
        yn = input("추가로 가입?(y/n): ")
        if yn.lower() == 'n':
            print('프로그램을 종료합니다')
            break
    except Exception as e:
        print('다시 입력하세요')

cur.close()
db.close()
# Out:
# 다시 입력하세요

# %%
# 강사가 한 거

db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

while True:
    try:
        userid = input('아이디를 입력하세요: ')
        userpw = input('비밀번호를 입력하세요: ')
        name = input('이름을 입력하세요: ')
        hp = input('전화번호를 입력하세요: ')
        email = input('이메일을 입력하세요: ')
        ssn1 = input('주민등록번호 앞자리를 입력하세요: ')
        ssn2 = input('주민등록번호 뒷자리를 입력하세요: ')
        zipcode = input('우편번호를 입력하세요: ')
        address1 = input('주소를 입력하세요: ')
        address2 = input('상세주소를 입력하세요: ')
        address3 = input('참고사항 입력하세요: ')
        gender = input('성별을 입력하세요(남자 또는 여자): ')
        sql = "insert into member (userid, userpw, name, hp, email, gender, ssn1, ssn2, zipcode, address1, address2, address3) values (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
        data = (userid, userpw, name, hp, email, gender, ssn1, ssn2, zipcode, address1, address2, address3)
        cur.execute(sql, data)
        db.commit()
        print('가입되었습니다!')
        yn = input('추가로 가입하시겠습니까? (y/n): ')
        if yn.lower() == 'n':
            print('프로그램을 종료합니다')
            break
    except Exception as e:
        print('다시 입력하세요')

cur.close()
db.close()

# %% [markdown]
# ### 로그인 프로그램

# %%
db = MySQLdb.connect(host = 'localhost', user = 'root', password = '1234', db = 'ai')
cur =  db.cursor(MySQLdb.cursors.DictCursor)   # userid userpw



while True:
    id = input("아이디 입력: ")

    sql = "SELECT userpw FROM member WHERE userid = %s"
    cur.execute(sql, (id,))






    '''
    c_pw = cur.fetchone()

    pw = input('비밀번호 입력: ')     

    if c_pw == pw:
        print('로그인 성공: ')
    else:
        print("아이디부터 다시 입력")
        continue'''

# %%
# 강사가 한 거

db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

userid = input('아이디를 입력하세요')
userpw = input('비밀번호를 입력하세요')

sql = "select idx from member where userid=%s and userpw=%s"
 
# sql = "select idx from member where userid="+ userid + "and userpw=" + userpw + "'"
# sql = f"select idx from member where userid={userid} and userpw={userpw}" 
# 변수자리에 쿼리를 넣어서 sql injection이 발생할 수 있어서 안좋다

data = (userid, userpw)
result = cur.execute(sql, data)

if result > 0:
    print('로그인 되었습니다')
else:
    print('아이디 또는 비밀번호를 확인하세요')

cur.close()
db.close()
# Out:
# 아이디 또는 비밀번호를 확인하세요

# %% [markdown]
# ### 회원정보 수정

# %%
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

while True:
    try:
        userid = input('아이디를 입력하세요: ')
        name = input('이름을 입력하세요: ')
        hp = input('전화번호를 입력하세요: ')
        email = input('이메일을 입력하세요: ')
        ssn1 = input('주민등록번호 앞자리를 입력하세요: ')
        ssn2 = input('주민등록번호 뒷자리를 입력하세요: ')
        zipcode = input('우편번호를 입력하세요: ')
        address1 = input('주소를 입력하세요: ')
        address2 = input('상세주소를 입력하세요: ')
        address3 = input('참고사항 입력하세요: ')
        gender = input('성별을 입력하세요(남자 또는 여자): ')

        sql = "UPDATE member SET userid = userid, name = %s, hp = %s, email= %s, gender= %s, ssn1=%s, ssn2=%s, zipcode=%s, address1=%s, address2=%s, address3= %s WHERE userpw = %s"
        data = (userid, userpw, name, hp, email, gender, ssn1, ssn2, zipcode, address1, address2, address3)
        cur.execute(sql, data)
        db.commit()

    except Exception as e:
        print('다시 입력')

cur.close()
db.close()

# %%
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

while True:
    try:
        userid = input('변경할 아이디를 입력하세요: ')
        name = input('이름을 입력하세요: ')
        hp = input('전화번호를 입력하세요: ')
        email = input('이메일을 입력하세요: ')
        ssn1 = input('주민등록번호 앞자리를 입력하세요: ')
        ssn2 = input('주민등록번호 뒷자리를 입력하세요: ')
        zipcode = input('우편번호를 입력하세요: ')
        address1 = input('주소를 입력하세요: ')
        address2 = input('상세주소를 입력하세요: ')
        address3 = input('참고사항 입력하세요: ')
        gender = input('성별을 입력하세요(남자 또는 여자): ')
        sql = "update member set name=%s, hp=%s, email=%s, ssn1=%s, ssn2=%s, zipcode=%s, address1=%s, address2=%s, address3=%s, gender=%s where userid=%s"
        data = (name, hp, email, ssn1, ssn2, zipcode, address1, address2, address3, gender, userid)
        result = cur.execute(sql, data)
        db.commit()

        if result > 0:
            print('변경되었습니다')
        else:
            print('에러!')

        yn = input('추가로 변경하겠습니까? (y/n): ')
        if yn.lower() == 'n':
            print('프로그램을 종료합니다')
            break

    except Exception as e:
        print('다시 입력하세요')


cur.close()
db.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 32
#      28         if yn.lower() == 'n':
#      29             print('프로그램을 종료합니다')
#      30             break
#      31
# ---> 32     except Exception as e:
#      33         print('다시 입력하세요')
#      34
#      35
#
# File c:\heeseung\03_Database\venv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File c:\heeseung\03_Database\venv\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ### 회원 탈퇴

# %%
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

id = input("삭제 아이디 입력: ")

sql = "DELETE FROM member where userid = %s"
data = (id,)
result = cur.execute(sql, data)

db.commit()

if result > 0:
    print('삭제 됨')
else:
    print('에러!')

cur.close()
db.close()

# %%
# 내가 강사 따라
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

userid = input("탈퇴할 아이디 입력: ")
sql = "DELETE FROM member where userid = %s "
result = cur.execute(sql, (userid,))
db.commit()

if result>0:
    print('탈퇴됨')
else:
    print('오류')


cur.close()
db.close()

# %%
# 강사
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

userid = input('탈퇴할 아이디를 입력하세요: ')
sql = 'delete from member where userid=%s'
result = cur.execute(sql, (userid,))
db.commit()

if result > 0:
    print('탈퇴되었습니다')
else:
    print('오류')

cur.close()
db.close()
